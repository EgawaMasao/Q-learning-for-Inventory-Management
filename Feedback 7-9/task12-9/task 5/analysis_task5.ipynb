# %% [markdown]
# # Analysis Task 5 - 3 SKU Groups (Fast/Medium/Slow 73 SKU)
# Sau khi train xong 6 runs (DQN Fast/Medium/Slow + A2C_mod Fast/Medium/Slow) với 73 SKU và action 14, file này sẽ load 6 checkpoints + logs + baseline 220 (ckpt-43) để tính:
# 1. Bảng so sánh performance giữa Fast/Medium/Slow vs baseline 220 cho DQN và A2C_mod (reward, service, holding, waste, ordering, stockout) trên data_grouped/group_*/test.tfrecords (504 periods)
# 2. SHAP Top-k per group (73*3=219 features) để xem pattern Sales dominant có giữ ở từng group không
# Output: task 5/output/comparison_3groups.csv + figure performance_vs_sku_group.png

# %%
import os, pandas as pd, numpy as np
print('Analysis Task 5 placeholder - sẽ load 6 checkpoints từ output/checkpoints_*/ và baseline 220')
print('Chạy evaluation trên data_grouped/group_fast/test.tfrecords etc')
